# %%
messages = ["Hi", "Welcome to the platform", "OK"]
le = []
for i in messages:
    l = len(i)
    le.append(l)
    print(i, l)
# Out:
# Hi 2
# Welcome to the platform 23
# OK 2

# %%
for i in range (len(le)):
    if le[i]>10:
        print("Message:\"",messages[i],"\"is flagged")
# Out:
# Message:" Welcome to the platform "is flagged
