# %%
u = "admin"
p = "1234"

# %%
eu = input("Enter user name:")
ep = input("Enter passsword:")
# Out:
# Enter user name: admin
# Enter passsword: 1234

# %%
if (eu == u and ep == p):
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful
