# %%
marks = [45,78,90,33,60]
p = 0
f = 0

# %%
for i in marks:
    if i>=50:
        p+=1
    else:
        f+=1

# %%
print("No of students pass:", p)
print("No of students fail:", f)
# Out:
# No of students pass: 3
# No of students fail: 2
