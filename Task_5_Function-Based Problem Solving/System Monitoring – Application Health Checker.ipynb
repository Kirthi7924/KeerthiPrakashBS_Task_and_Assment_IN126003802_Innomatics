# %%
def health_check(count):
    if count==0:
        status = "Healthy"
    elif count<=5:
        status = "Minor issues"
    else:
        status = "Critical issues"
    print("System status:",status)
count = int(input("Enter the error count:"))
print("Error count:",count)
health_check(count)
# Out:
# Enter the error count: 7
# Error count: 7
# System status: Critical issues
