# %%
def check(s):
    for i, j in s.items():
        if j < 15:
            print(i, ":Reorder Alert")
        else:
            print(i, ":Stock OK")
s = {
    "Rice": 10,
    "Sugar": 25,
    "Oil": 12,
    "Soap": 40,
    "Milk Powder": 14
}
check(s)
# Out:
# Rice :Reorder Alert
# Sugar :Stock OK
# Oil :Reorder Alert
# Soap :Stock OK
# Milk Powder :Reorder Alert
