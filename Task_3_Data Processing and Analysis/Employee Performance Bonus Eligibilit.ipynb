# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

h = max(employees.values())
t = []

for i in employees:
    if employees[i] == h:
        t.append(i)

print("Top Performers Eligible for Bonus:", ", ".join(t), "(Score:", h, ")")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92 )
