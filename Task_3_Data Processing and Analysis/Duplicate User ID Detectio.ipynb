# %%
ui = ["user1", "user2", "user1", "user3", "user1", "user3"]
c = {}
for i in ui:
    if i not in c:
       c[i] = 1
    else:
       c[i] += 1

for i in c:
    if c[i] > 1:
        print(f"{i} → {c[i]} times")
# Out:
# user1 → 3 times
# user3 → 2 times
