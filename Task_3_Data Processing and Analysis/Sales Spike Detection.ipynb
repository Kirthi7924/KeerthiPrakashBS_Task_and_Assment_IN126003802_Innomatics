# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

a = sum(sales) / len(sales)
t = a * 1.3

for i in range(len(sales)):
    if sales[i] > t:
        print("Day",i,":",sales[i]) in
# Out:
# Day 5 : 3000
