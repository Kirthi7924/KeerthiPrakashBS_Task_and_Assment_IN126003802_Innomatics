# %%
s = input("Enter a sentence:")
s = s.lower()

w = s.split()
c = {}

for i in w:
    if i not in c:
        c[i] = 1
    else:
        c[i] += 1

r = {}
for i, j in c.items():
    if j > 1:
        r[i] = j

print(r)
# Out:
# Enter a sentence:Buy mobile phone buy phone online
# {'buy': 2, 'phone': 2}
