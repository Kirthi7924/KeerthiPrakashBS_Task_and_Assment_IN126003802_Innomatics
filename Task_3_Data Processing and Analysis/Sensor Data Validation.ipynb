# %%
sr = [3, 4, 7, 8, 10, 12, 5]

v = []

for i, j in enumerate(sr):
    if j % 2 == 0:
        v.append((i, j))

print("Valid Sensor Readings (Hour, Value):")
print(v)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]
