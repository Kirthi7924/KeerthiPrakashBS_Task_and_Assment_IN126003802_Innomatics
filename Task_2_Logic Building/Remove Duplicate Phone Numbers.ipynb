# %%
pn = [9876543210, 9123456789, 9876543210]
upn = set(pn)
print("Unique numbers:",upn)
# Out:
# Unique numbers: {9876543210, 9123456789}

# %%
upn1 = []
for i in pn:
    if i not in upn1:
        upn1.append(i)
print("Unique numbers:",upn1)
# Out:
# Unique numbers: [9876543210, 9123456789]
